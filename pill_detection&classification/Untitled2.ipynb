# %%
import os
import pandas as pd

# %%
df = pd.read_csv('handcrop_df.csv')

# %%
nlist = list()
for name in df['img']:
    nlist.append(name.split('_')[0])

# %%
dat = pd.DataFrame({'class':nlist, 'img':df['img']})

# %%
a = '14_314'

# %%
a.split('_')
# Out:
# ['14', '314']

# %%
dat
# Out:
#          class              img
# 0    625900040  625900040_0.jpg
# 1    625900040  625900040_1.jpg
# 2    625900050  625900050_0.jpg
# 3    625900050  625900050_1.jpg
# 4    625900060  625900060_0.jpg
# ..         ...              ...
# 174  694000600  694000600_1.jpg
# 175  694000670  694000670_0.jpg
# 176  694000670  694000670_1.jpg
# 177  697100230  697100230_0.jpg
# 178  697100230  697100230_1.jpg
#
# [179 rows x 2 columns]

# %%
df['class'] = []
for i in range(len(df)):
    df['class'] = df['img'][i][:-4]
# Out:
# '625900060_0.jpg'

# %%
dat.to_csv('handcrop_df2.csv', index=False)

# %%
len(dat['class'].unique())
# Out:
# 90
