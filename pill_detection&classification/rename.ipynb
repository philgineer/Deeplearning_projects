# %%
import os

# %%
list = os.listdir('./handcrop/')
list
# Out:
# ['625900040_0.jpg',
#  '625900040_1.jpg',
#  '625900050_0.jpg',
#  '625900050_1.jpg',
#  '625900060_0.jpg',
#  '625900060_1.jpg',
#  '625900090_0.jpg',
#  '625900090_1.jpg',
#  '641600030_0.jpg',
#  '641600030_1.jpg',
#  '641600210_0.jpg',
#  '641600210_1.jpg',
#  '641601790_0.jpg',
#  '641601790_1.jpg',
#  '641601800_0.jpg',
#  '641601800_1.jpg',
#  '641601880_0.jpg',
#  '641601880_1.jpg',
#  '641602000_0.jpg',
#  '641602000_1.jpg',
#  '641602040_0.jpg',
#  '641602040_1.jpg',
#  '641602060_0.jpg',
#  '641602060_1.jpg',
#  '641605230_0.jpg',
#  '641605230_1.jpg',
#  '641702920_0.jpg',
#  '641702920_1.jpg',
#  '641806060_0.jpg',
#  '641806060_1.jpg',
#  '641905450_0.jpg',
#  '641905450_1.jpg',
#  '642100980_0.jpg',
#  '642100980_1.jpg',
#  '642200220_0.jpg',
#  '642200220_1.jpg',
#  '642202020_0.jpg',
#  '642202020_1.jpg',
#  '642203380_0.jpg',
#  '642203380_1.jpg',
#  '642500950_0.jpg',
#  '642500950_1.jpg',
#  '642502290_0.jpg',
#  '642502290_1.jpg',
#  '642503410_0.jpg',
# ...

# %%
for i in range(len(list)):
    if i % 2 == 1:
        os.rename('./soncrop/' + list[i], './soncrop/' + list[i][:-4] + '_0' + '.jpg')
    if i % 2 == 0:
        os.rename('./soncrop/' + list[i], './soncrop/' + list[i][:-6] + '_1' + '.jpg')

# %%
os.listdir('./soncrop/')
# Out:
# ['642100980_0.jpg',
#  '642100980_1.jpg',
#  '642200220_0.jpg',
#  '642200220_1.jpg',
#  '642202020_0.jpg',
#  '642202020_1.jpg',
#  '642203380_0.jpg',
#  '642203380_1.jpg',
#  '642500950_0.jpg',
#  '642500950_1.jpg',
#  '642502290_0.jpg',
#  '642502290_1.jpg',
#  '642503410_0.jpg',
#  '642503410_1.jpg',
#  '642503430_0.jpg',
#  '642503430_1.jpg',
#  '642503760_0.jpg',
#  '642503760_1.jpg',
#  '642505070_0.jpg',
#  '642505070_1.jpg',
#  '642506570_0.jpg',
#  '642506570_1.jpg',
#  '642901000_0.jpg',
#  '642901000_1.jpg',
#  '642901010_0.jpg',
#  '642901010_1.jpg',
#  '642902200_0.jpg',
#  '642902200_1.jpg',
#  '643300380_0.jpg',
#  '643300380_1.jpg',
#  '643301790_0.jpg',
#  '643301790_1.jpg',
#  '643302280_0.jpg',
#  '643302280_1.jpg',
#  '643303700_0.jpg',
#  '643303700_1.jpg',
#  '643304110_0.jpg',
#  '643304110_1.jpg',
#  '643304610_0.jpg',
#  '643304610_1.jpg',
#  '643501600_0.jpg',
#  '643501600_1.jpg',
#  '643502370_0.jpg',
#  '643502370_1.jpg',
#  '643504310_0.jpg',
# ...

# %%
list[i][:-4]
# Out:
# '697100230'

# %%
list = os.listdir('./first_drug')
list
# Out:
# ['625900040_y.jpg',
#  '625900050_y.jpg',
#  '625900060_y.jpg',
#  '625900090_y.jpg',
#  '641600030_y.jpg',
#  '641600210_y.jpg',
#  '641601790_y.jpg',
#  '641601800_y.jpg',
#  '641601880_y.jpg',
#  '641602000_y.jpg',
#  '641602040_y.jpg',
#  '641602060_y.jpg',
#  '641605230_y.jpg',
#  '641702920_y.jpg',
#  '641806060_y.jpg',
#  '641905450_y.jpg',
#  '642100980_y.jpg',
#  '642200220_y.jpg',
#  '642202020_y.jpg',
#  '642203380_y.jpg',
#  '642500950_y.jpg',
#  '642502290_y.jpg',
#  '642503410_y.jpg',
#  '642503430_y.jpg',
#  '642503760_y.jpg',
#  '642505070_y.jpg',
#  '642506570_y.jpg',
#  '642901000_y.jpg',
#  '642901010_y.jpg',
#  '642902200_y.jpg',
#  '643300380_y.jpg',
#  '643301790_y.jpg',
#  '643302280_y.jpg',
#  '643303700_y.jpg',
#  '643304110_y.jpg',
#  '643304610_y.jpg',
#  '643501600_y.jpg',
#  '643502370_y.jpg',
#  '643504310_y.jpg',
#  '643504680_y.jpg',
#  '643504690_y.jpg',
#  '643507260_y.jpg',
#  '643507280_y.jpg',
#  '644308510_y.jpg',
#  '644700140_y.jpg',
# ...

# %%
import pandas as pd
df = pd.DataFrame(list, columns=['img'])
df
# Out:
#                  img
# 0    625900040_0.jpg
# 1    625900040_1.jpg
# 2    625900050_0.jpg
# 3    625900050_1.jpg
# 4    625900060_0.jpg
# ..               ...
# 174  694000600_1.jpg
# 175  694000670_0.jpg
# 176  694000670_1.jpg
# 177  697100230_0.jpg
# 178  697100230_1.jpg
#
# [179 rows x 1 columns]

# %%
df.to_csv('handcrop_df.csv', index=False)
